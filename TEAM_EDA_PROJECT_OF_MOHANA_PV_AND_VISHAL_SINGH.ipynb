# %% [markdown]
# <a href="https://colab.research.google.com/github/ssinghvishal/CAPSTONE_EDA_PROJECT/blob/main/TEAM_EDA_PROJECT_OF_MOHANA_PV_AND_VISHAL_SINGH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Capstone Project: Exploratory Data Analysis on The Global Terrorism Database (GTD)**

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Team
# ##### **Team Member 1 -**Mohana P V
# ##### **Team Member 2 -**Vishal Singh

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The Global Terrorism Database (GTD) documents more than 180000 international and domestic terrorist attacks that occurred worldwide since 1970.This project is on Global Terrorism Data menas in this project there are some data about terrorist incident happen in the world . And which country or region are affected from terrorism the most . In this data there are 135 thing given.In which year specified the attack of the yaer ,date of attack , country , region , city , state , logitude , latitude , summary of the attack in which how many people died and how many injurd , type of attack , group that take the responsibility of the attack , wepon used in attack , committee form after the attack and who is responsible for the attack and so on many useful data given in this data set. This dataset is given from date 1970 to 2017 means in this data every attack happend between 1970 to 2017 is given which is very useful for security of the country. From given data we can find out which regions which country affectd the most and what steps shoud be taken so that we can prevent the ferthure that should not happen in future. We can see that the type of attack happening on the country and what effect it cause on the country and how many lives would lost due to attacks . We can see that the frequency of attack happening every year and it is reducing or increasing and which region it is reducing and which region it is increasing and the country who is controling the attack or did not do any thing . Which type of wepon used in the attack and what that wepon harms the people menas that how much it is lethal for the humanity . In this data there are summary of attack which is written on summary section in which there are summary of whole incident means who is the attacker and who is the defender and what casulities cause by the attacker and what are the damages done by the attacker how many attacker are there and who is captured alive and who is died in the line of fire. In the data there are mentioned the type of attack means what is the motive of the attack either it is assissination or kidnaping or robbery or bombing or assult or mass shooting  and so on . And in this data there are also mention that the type of attack which means attack happen on private property or gorvment official or media house or school and so on. In data set there are mention a column that told about the people died in the attack and the name of or designation of the person who is died in the attack and the nationality of that person who is died in the attack . In this data set there are also mention the gang name who done the attack and motive behind the attack which was done by the gang member or the orgniser of the attack. This project aims to have a profound impact on global counterterrorism efforts by leveraging the GTD as a critical resource. By combining rigorous data analysis, policy recommendations, and academic contributions, the project seeks to empower governments and organizations to address terrorism with a deeper understanding of its underlying dynamics and develop strategies that enhance security, promote peace, and protect societies worldwide.
#
# **Expected Outcomes of the project:**
#
# ->Comprehensive Pandas DataFrames containing structured GTD data.
#
# ->Enhanced data exploration capabilities, enabling deeper insights into terrorism trends.
#
# ->Informative data visualizations and statistical analysis results.
#
# ->Improved understanding of the factors contributing to terrorism.
#
# ->Insights that can inform counterterrorism strategies and policies.
#
# **Impact**:
#
# This project seeks to empower data scientists, researchers, and analysts by providing them with a powerful toolset for exploring and analyzing the GTD data efficiently. By leveraging Pandas DataFrames, the project aims to facilitate evidence-based decision-making, advance our understanding of global terrorism dynamics, and ultimately contribute to the development of more effective counterterrorism strategies and policies.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The Global Terrorism Database (GTD) is a valuable resource for understanding global terrorism trends and patterns. However, the use of the GTD for advanced data analysis with Pandas DataFrames presents several significant challenges and limitations, which need to be addressed to unlock its full potential for data-driven insights and decision-making.
# This problem statement can be broken down into specific analysis tasks and questions:
#
# **1. Data Preparation and Cleaning:**
# Acquire and load the GTD dataset into a pandas DataFrame.
# Filter the data to include records . Handle missing values, correct data types, and perform data cleaning as necessary.
#
# **2.Pattern Analysis:**
# Analyze trends in terrorism incidents in the world over the specified decade.
# Explore patterns related to the types of attacks (e.g., bombings, shootings), target types (e.g., civilians, military), and attack methods (e.g., explosives, firearms).
#
# **3.Factors Identification:**
# Perform statistical analysis and visualizations to understand correlations and associations between these factors and terrorism incidents.
#
# **4.Hotspot Identification:**
# Determine regions or cities that are most affected by terrorism.
# Create heatmaps or geographical visualizations to pinpoint high-activity areas.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# "To analyze global terrorism trends over the past decade and identify regions with increasing terrorist activities to assist international security agencies in deploying resources more effectively."
#
# With this business objective in mind, you can break it down into specific analysis tasks and questions:
#
# **1. Data Preparation and Cleaning:**
#
# Load the GTD dataset into a pandas DataFrame.
# Filter the data to include only records from 1970 to 2017.
# Handle missing values, correct data types, and perform necessary data cleaning steps.
#
# **2. Trend Analysis:**
#
# Calculate the annual number of terrorist incidents worldwide over the specified period.
# Visualize the trends in terrorism incidents using line charts or time series analysis.
#
# **3. Region Identification:**
#
# Identify regions or countries with the highest and lowest increases in terrorist activities over the decade.
# Group data by regions and calculate statistics like the total number of incidents, fatalities, or changes in attack methods.
#
# **4.Hotspot Mapping:**
#
# Create geographical heatmaps or choropleth maps to visualize regions with increasing terrorism activities.
# Utilize latitude and longitude information to pinpoint specific locations of incidents.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime as datetime

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
filepath='/content/drive/MyDrive/Global Terrorism Data .csv'

# %%
df_gtd=pd.read_csv(filepath , encoding = 'ISO-8859-1')
# Out:
# <ipython-input-47-6c3be2d2fff6>:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_gtd=pd.read_csv(filepath , encoding = 'ISO-8859-1')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df_gtd
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# ...

# %% [markdown]
# # **Data Set top head vivew**

# %%
df_gtd.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %% [markdown]
# # **Data Set bottom vivew**

# %%
df_gtd.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
row=len(df_gtd.axes[0])
cols=len(df_gtd.axes[1])
print("The no of row:",row)
print("The no of columns:",cols)
# Out:
# The no of row: 181691
# The no of columns: 135

# %% [markdown]
# **Or**

# %%
df_gtd.shape
# Out:
# (181691, 135)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df_gtd.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 135 columns):
#  #    Column              Dtype
# ---   ------              -----
#  0    eventid             int64
#  1    iyear               int64
#  2    imonth              int64
#  3    iday                int64
#  4    approxdate          object
#  5    extended            int64
#  6    resolution          object
#  7    country             int64
#  8    country_txt         object
#  9    region              int64
#  10   region_txt          object
#  11   provstate           object
#  12   city                object
#  13   latitude            float64
#  14   longitude           float64
#  15   specificity         float64
#  16   vicinity            int64
#  17   location            object
#  18   summary             object
#  19   crit1               int64
#  20   crit2               int64
#  21   crit3               int64
#  22   doubtterr           float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
s=df_gtd.duplicated()
g=df_gtd.duplicated().sum()
print(s)
print("Total dublicate value in data set is:",g)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 181686    False
# 181687    False
# 181688    False
# 181689    False
# 181690    False
# Length: 181691, dtype: bool
# Total dublicate value in data set is: 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(" \nCount total NaN at each column in a DataFrame : \n\n",df_gtd.isnull().sum())
# Out:
#
# Count total NaN at each column in a DataFrame :
#
#  eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %% [markdown]
# **Or**

# %%
df_gtd.isna().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
# Visualizing the missing values
print(" \nshow the boolean Dataframe : \n\n", df_gtd.isnull())
# Out:
#
# show the boolean Dataframe :
#
#          eventid  iyear  imonth   iday  approxdate  extended  resolution  \
# 0         False  False   False  False        True     False        True
# 1         False  False   False  False        True     False        True
# 2         False  False   False  False        True     False        True
# 3         False  False   False  False        True     False        True
# 4         False  False   False  False        True     False        True
# ...         ...    ...     ...    ...         ...       ...         ...
# 181686    False  False   False  False        True     False        True
# 181687    False  False   False  False        True     False        True
# 181688    False  False   False  False        True     False        True
# 181689    False  False   False  False        True     False        True
# 181690    False  False   False  False        True     False        True
#
# ...

# %% [markdown]
# **or**

# %%
plt.figure(figsize=(30, 10))
sns.barplot(x=df_gtd.columns, y=df_gtd.isna().sum())
plt.xlabel('Columns')
plt.ylabel('Count of Missing Values')
plt.title('Missing Values in Each Column')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# **Dataset Size:** The data set is quite large containing 181,691 rows and 135 columns.
#
# **Data Types:** The type of dataset columns are float64, int64 , object and total columns conatain float value is 55 and int vale is 22 and object value is 58.
#
# **Missing Values:** There are some columns with large number of missing values.|For example, in the 'approxdate' column has 172,452 missing values and the 'related' column has 156,653 missing values. However 23 columns do not have any missing values.
#
# **Memory:** The Dataset uses over 187.1 MB of memory.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
columns_name= df_gtd.columns
print([column for column in columns_name])
# Out:
# ['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended', 'resolution', 'country', 'country_txt', 'region', 'region_txt', 'provstate', 'city', 'latitude', 'longitude', 'specificity', 'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3', 'doubtterr', 'alternative', 'alternative_txt', 'multiple', 'success', 'suicide', 'attacktype1', 'attacktype1_txt', 'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt', 'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt', 'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2', 'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2', 'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt', 'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3', 'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2', 'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2', 'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed', 'claimmode', 'claimmode_txt', 'claim2', 'claimmode2', 'cla
# ...

# %%
# Dataset Describe
df_gtd.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **eventid**: Incidents from the GTD follow a 12-digit Event ID system.
#
# • First 8 numbers – date recorded “yyyymmdd”.
#
# • Last 4 numbers – sequential case number for the given day (0001, 0002 etc).
#
# **iyear**: This field contains the year in which the incident initiated.
#
# **imonth**: the month in which the incident occurred.
#
# **iday**: The day when the incident was initiated.
#
# **country_txt**: Name of the country where the terrorist attack occured.
#
# **region_txt**: Name of the region where the terrorist attack occured.
#
# **provstate**: The name of the state where the terrorist attack occured.
#
# **city**: Name of the city, village, or town where the terrorist attack occured.
#
# **latitude**: Records the latitude of the city in which the event occurred.
#
# **longitude**: Records the longitude of the city in which the event occurred.
#
# **summary**: The short summary of attack .
#
# **attacktype1_txt**: General method of attack employed.
#
# **success:** Success of a terrorist strike is defined according to the tangible effects of the attack.
#
# **targtype1_txt:** The specific person, building, installation, etc. that is targeted.
#
# **targsubtype1_txt**:The person or body attack by perticular.
#
# **natlty1_txt:** The nationality of the target that was attacked.
#
# **gname:** The name of the group that carried out the attack.
#
# **weaptype1_txt:**  The general type of weapon used in the incident.
#
# **weapdetail**: Perticular wepon use for attack.
#
# **nkill:** The number of total confirmed fatalities.
#
# **nwound:** The number of total confirmed wounded.Answer Here
#
# **propextent_txt**: Loss due to attack

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for column in df_gtd.columns:
    unique_values = df_gtd[column].unique()
    print(f"Unique values in '{column}':\n{unique_values}\n")
    print('****************')
    print("################")
    print('****************')
    print("################")
# Out:
# Unique values in 'eventid':
# [197000000001 197000000002 197001000001 ... 201712310030 201712310031
#  201712310032]
#
# ****************
# ################
# ****************
# ################
# Unique values in 'iyear':
# [1970 1971 1972 1973 1974 1975 1976 1977 1978 1979 1980 1981 1986 1982
#  1983 1984 1985 1987 1988 1989 1990 1991 1992 1994 1995 1996 1997 1998
#  1999 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012
#  2013 2014 2015 2016 2017]
#
# ****************
# ################
# ****************
# ################
# Unique values in 'imonth':
# [ 7  0  1  2  3  4  5  6  8  9 10 11 12]
#
# ****************
# ################
# ****************
# ################
# Unique values in 'iday':
# [ 2  0  1  3  6  8  9 10 11 12 13 14 15 19 20 21 22 25 26 27 28 30 31  4
#   7 16 17 18 23 24  5 29]
#
# ****************
# ################
# ****************
# ################
# Unique values in 'approxdate':
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
df_gtd.rename(columns={'iyear': 'Year', 'imonth': 'Month', 'iday': 'Day', 'country_txt': 'Country', 'region_txt': 'Region','provstate':'state', 'city': 'City', 'attacktype1_txt': 'Attack_Type', 'targtype1_txt': 'Target_Type',"natlty1_txt":"target_nationality", 'gname': 'Group_Name', 'weaptype1_txt': 'Weapon_Type', 'nkill': 'Killed', 'nwound': 'Injured'}, inplace=True)
df_gtd = df_gtd[['Year', 'Month', 'Day', 'Country', 'Region','state', 'City', 'latitude', 'longitude', 'Attack_Type', 'success', 'Target_Type',"target_nationality", 'Group_Name', 'Weapon_Type', 'Killed', 'Injured',"dbsource"]]
df_gtd.head()
# Out:
#    Year  Month  Day             Country                       Region    state  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean      NaN
# 1  1970      0    0              Mexico                North America  Federal
# 2  1970      1    0         Philippines               Southeast Asia   Tarlac
# 3  1970      1    0              Greece               Western Europe   Attica
# 4  1970      1    0               Japan                    East Asia  Fukouka
#
#             City   latitude   longitude                     Attack_Type  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2        Unknown  15.478598  120.599741                   Assassination
# 3         Athens  37.997490   23.762728               Bombing/Explosion
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
#
#    success                  Target_Type  target_nationality  \
# ...

# %%
df_gtd.shape
# Out:
# (181691, 18)

# %%
df_gtd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 18 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Year                181691 non-null  int64
#  1   Month               181691 non-null  int64
#  2   Day                 181691 non-null  int64
#  3   Country             181691 non-null  object
#  4   Region              181691 non-null  object
#  5   state               181270 non-null  object
#  6   City                181257 non-null  object
#  7   latitude            177135 non-null  float64
#  8   longitude           177134 non-null  float64
#  9   Attack_Type         181691 non-null  object
#  10  success             181691 non-null  int64
#  11  Target_Type         181691 non-null  object
#  12  target_nationality  180132 non-null  object
#  13  Group_Name          181691 non-null  object
#  14  Weapon_Type         181691 non-null  object
# ...

# %%
df_gtd.isna().sum()
# Out:
# Year                      0
# Month                     0
# Day                       0
# Country                   0
# Region                    0
# state                   421
# City                    434
# latitude               4556
# longitude              4557
# Attack_Type               0
# success                   0
# Target_Type               0
# target_nationality     1559
# Group_Name                0
# Weapon_Type               0
# Killed                10313
# Injured               16311
# dbsource                  0
# dtype: int64

# %%
df_Killed = df_gtd['Killed'].mode().iloc[0]
df_gtd.loc[:, 'Killed'] = df_gtd['Killed'].fillna(df_Killed)

df_Injured = df_gtd['Injured'].mode().iloc[0]
df_gtd.loc[:, 'Injured'] = df_gtd['Injured'].fillna(df_Injured)
# Out:
# <ipython-input-52-e11ec74ae794>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gtd.loc[:, 'Killed'] = df_gtd['Killed'].fillna(df_Killed)
# <ipython-input-52-e11ec74ae794>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gtd.loc[:, 'Injured'] = df_gtd['Injured'].fillna(df_Injured)

# %%
df_gtd.dropna(inplace= True)
df_gtd.reset_index().head()
# Out:
# <ipython-input-53-d7c4c290fdc6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gtd.dropna(inplace= True)
#    index  Year  Month  Day        Country          Region     state  \
# 0      1  1970      0    0         Mexico   North America   Federal
# 1      2  1970      1    0    Philippines  Southeast Asia    Tarlac
# 2      3  1970      1    0         Greece  Western Europe    Attica
# 3      4  1970      1    0          Japan       East Asia   Fukouka
# 4      5  1970      1    1  United States   North America  Illinois
#
#           City   latitude   longitude                     Attack_Type  \
# 0  Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 1      Unknown  15.478598  120.599741                   Assassination
# ...

# %%
df_gtd.isna().sum()
# Out:
# Year                  0
# Month                 0
# Day                   0
# Country               0
# Region                0
# state                 0
# City                  0
# latitude              0
# longitude             0
# Attack_Type           0
# success               0
# Target_Type           0
# target_nationality    0
# Group_Name            0
# Weapon_Type           0
# Killed                0
# Injured               0
# dbsource              0
# dtype: int64

# %%
df_gtd.describe()
# Out:
#                 Year          Month            Day       latitude  \
# count  174789.000000  174789.000000  174789.000000  174789.000000
# mean     2002.890760       6.467981      15.514289      23.452931
# std        13.227524       3.387600       8.808758      18.597978
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.438570
# 50%      2009.000000       6.000000      15.000000      31.408822
# 75%      2014.000000       9.000000      23.000000      34.671391
# max      2017.000000      12.000000      31.000000      74.633553
#
#           longitude        success         Killed        Injured
# count  1.747890e+05  174789.000000  174789.000000  174789.000000
# mean  -4.654796e+02       0.890193       2.240942       2.933119
# std    2.061481e+05       0.312650      11.231165      34.948739
# min   -8.618590e+07       0.000000       0.000000       0.000000
# ...

# %%
df_gtd.describe(include='all')
# Out:
#                  Year          Month            Day Country  \
# count   174789.000000  174789.000000  174789.000000  174789
# unique            NaN            NaN            NaN     204
# top               NaN            NaN            NaN    Iraq
# freq              NaN            NaN            NaN   24444
# mean      2002.890760       6.467981      15.514289     NaN
# std         13.227524       3.387600       8.808758     NaN
# min       1970.000000       0.000000       0.000000     NaN
# 25%       1991.000000       4.000000       8.000000     NaN
# 50%       2009.000000       6.000000      15.000000     NaN
# 75%       2014.000000       9.000000      23.000000     NaN
# max       2017.000000      12.000000      31.000000     NaN
#
#                             Region    state     City       latitude  \
# count                       174789   174789   174789  174789.000000
# unique                          12     2810    34767            NaN
# ...

# %%
df_gtd["Country"].nunique()
# Out:
# 204

# %%
print('Top 5 countries with highest number of terrorist attacks:')
df_gtd["Country"].value_counts().head()
# Out:
# Top 5 countries with highest number of terrorist attacks:
# Iraq           24444
# Pakistan       14244
# Afghanistan    11781
# India          11776
# Colombia        7810
# Name: Country, dtype: int64

# %%
print('Top 5 Regions with highest number of terrorist attacks:')
df_gtd['Region'].value_counts().head()
# Out:
# Top 5 Regions with highest number of terrorist attacks:
# Middle East & North Africa    49268
# South Asia                    43498
# South America                 18048
# Sub-Saharan Africa            16891
# Western Europe                16294
# Name: Region, dtype: int64

# %%
print('Top 5 cities with highest number of terrorist attacks:')
df_gtd[df_gtd['City']!='Unknown']['City'].value_counts().head()
# Out:
# Top 5 cities with highest number of terrorist attacks:
# Baghdad    7583
# Karachi    2609
# Lima       2349
# Mosul      2263
# Belfast    2166
# Name: City, dtype: int64

# %%
df_gtd['Casualties']= df_gtd['Killed']+ df_gtd['Injured']
df_gtd.head(1)
# Out:
# <ipython-input-39-8fe14161ddf3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gtd['Casualties']= df_gtd['Killed']+ df_gtd['Injured']
#    Year  Month  Day Country         Region    state         City   latitude  \
# 1  1970      0    0  Mexico  North America  Federal  Mexico city  19.371887
#
#    longitude                  Attack_Type  success              Target_Type  \
# 1 -99.086624  Hostage Taking (Kidnapping)        1  Government (Diplomatic)
#
#   target_nationality                          Group_Name Weapon_Type  Killed  \
# 1            Belgium  23rd of September Communist League     Unknown     0.0
#
#    Injured dbsource  Casualties
# 1      0.0     PGIS         0.0

# %%
print('maximum number of casualties in a single terrorist attack')
df_gtd['Casualties'].max()
# Out:
# maximum number of casualties in a single terrorist attack
# 9574.0

# %%
print('most active 5 terrorist groups:')
df_gtd[df_gtd['Group_Name']!= 'Unknown']['Group_Name'].value_counts().head()
# Out:
# most active 5 terrorist groups:
# Taliban                                             7151
# Islamic State of Iraq and the Levant (ISIL)         5579
# Shining Path (SL)                                   4297
# Al-Shabaab                                          3225
# Farabundo Marti National Liberation Front (FMLN)    2980
# Name: Group_Name, dtype: int64

# %%
print('most used 5 weapons in terror activities:')
df_gtd[df_gtd['Weapon_Type']!='Unknown']['Weapon_Type'].value_counts().head()
# Out:
# most used 5 weapons in terror activities:
# Explosives    89634
# Firearms      56017
# Incendiary    10809
# Melee          3519
# Chemical        292
# Name: Weapon_Type, dtype: int64

# %%
print('Top 5 Target_Type person in terror activities:')
df_gtd[df_gtd['Target_Type']!='Unknown']['Target_Type'].value_counts().head()
# Out:
# Top 5 Target_Type person in terror activities:
# Private Citizens & Property    42044
# Military                       26824
# Police                         24045
# Government (General)           20648
# Business                       20074
# Name: Target_Type, dtype: int64

# %%
print('Top 5 target_nationality person in terror activities:')
df_gtd[df_gtd['target_nationality']!='Unknown']['target_nationality'].value_counts().head()
# Out:
# Top 5 target_nationality person in terror activities:
# Iraq           23985
# Pakistan       13842
# India          11932
# Afghanistan    10761
# Colombia        7473
# Name: target_nationality, dtype: int64

# %%
print('most used 5 Attack_Type  in terror activities:')
df_gtd[df_gtd['Attack_Type']!='Unknown']['Attack_Type'].value_counts().head()
# Out:
# most used 5 Attack_Type  in terror activities:
# Bombing/Explosion                 85467
# Armed Assault                     40647
# Assassination                     18640
# Hostage Taking (Kidnapping)       10588
# Facility/Infrastructure Attack    10082
# Name: Attack_Type, dtype: int64

# %%
print('Top 5 state attack  in terror activities:')
df_gtd[df_gtd['state']!='Unknown']['state'].value_counts().head()
# Out:
# Top 5 state attack  in terror activities:
# Baghdad             7639
# Northern Ireland    4486
# Balochistan         3705
# Saladin             3407
# Al Anbar            3295
# Name: state, dtype: int64

# %%
print('Top 5 source info  in terror activities:')
df_gtd[df_gtd['dbsource']!='Unknown']['dbsource'].value_counts().head()
# Out:
# Top 5 source info  in terror activities:
# START Primary Collection    76498
# PGIS                        59405
# ISVG                        16767
# CETIS                       15704
# CAIN                         1587
# Name: dbsource, dtype: int64

# %%
max_casualties_date_index = df_gtd['Casualties'].idxmax()
max_casualties_date = df_gtd.loc[max_casualties_date_index, ['Year', 'Month', 'Day']]
date_obj = datetime.datetime(max_casualties_date['Year'], max_casualties_date['Month'], max_casualties_date['Day'])
formatted_date = date_obj.strftime('%m/%d/%Y')
print('Date with the highest number of casualties:', formatted_date)
# Out:
# Date with the highest number of casualties: 09/11/2001

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# After analysing the code book and csv file of Global Terrorism Dataset We concluded that there are so many columns(135) which are not providing us too much useful information. So we will rename some column names for better understanding  then we will only extract some necessary columns for further analysis.
#
# There are many null values in killed and injured columns so we will those null values by the taking the mode of those columns and filled in the values in their respective columns.
#
# their are a little null values in **some** columns so we will directly drop them as there are app. 174789 rows available and we take 19 columns for further analysis.
#
# **Some Insights--**
#
# 1- 204 of 249(as of 2017) countries have reported terrorist activities at least once between 1970 and 2017.
#
# 2- The country faced most terrorist attacks is- **Iraq**
#
# 3- The region faced most terrorist attacks is- **Middle East and North Africa**
#
# 4- The city faced most terrorist attacks is- **Baghdad**
#
# 5- Maximum no of casualties in single terrorist attack- **9574**
#
# 6- Maximum no of casualties on date- **9/11/2011**
#
# 7- Most active terrorist group- **Taliban**
#
# 8- Most used weapon for terrorist activities- **Explosives**
#
# 9- Top state was attack by terrorist- **Baghdad**
#
# 10- Top wepon use for attack is -**Bombing**
#
# 11- Top info given of terrorist attack is- **START Primary Collection**

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
plt.figure(figsize=(14,8))
sns.countplot(data= df_gtd, x='Year')
plt.xlabel('Year')
plt.xticks(rotation=90)
plt.ylabel('Total no of attack happen per year')
plt.title('Total count of terrorist activities each year')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This graph represent the frequency of terrorist attack per year
#
# Most no of terrorist attack was done in 2014

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Trends**: This graph shows that the terrorist attack was rapidaly increasing
#
# **Peaks and Valleys:** There are noticeable peaks and valleys in certain years, suggesting variations in the occurrence of terrorist activities. These peaks might correspond to significant events or periods of heightened terrorist incidents.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive business impact-**
#
# **Strategic Planning:** Businesses can adapt their strategies based on terrorism trends, identifying safe regions, and developing country plans to ensure business continuity.
#
# **Partnerships and Collaborations:** They can colabrate with gorvenment and agency for safer enviorment and good intel about security.
#
# **Negative growth-**
#
# **Disruption of Operations**: Due to attack infrastructure might be damage and person might died that cause some problem in growth.
#
# **Increased Costs:** You have to take some security measures for saftey that might increase your cost.
#
# **Restricted Market Expansion:** Regulatory barriers and security concerns can limit market expansion efforts, limiting growth potential.
#
# **Economic Impact:** Due to terrorism economy might go down because of no fdi and tourism and negative impact on bussinuss.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
plt.figure(figsize=(10,7))
sns.countplot(data=df_gtd, x='Country', order=df_gtd['Country'].value_counts().head(15).index)
plt.xlabel('Country Victim of terrorism')
plt.xticks(rotation=90)
plt.ylabel('The No of attack happen on the country')
plt.title('Country that is victim of terrorisom ')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart shows the terror activity on the country by proper understanding means which country affected from terrorisom the most

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This chart provide us the no of total terrorist activity of top 15 country that
# should told us which is the most dangerous place for people to live
#
#
# Maximum terrorist activities in country: **Iraq**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can potentially help create a positive business impact. Understanding the countries with a high incidence of terrorist activities can be very risky for business you have to maintain high security for bussiness for the safty perpose
#
# **Negative-**
#
# The negative of this analyse is that we can do bussiness but if security mesure lack then we might hit by terrorist group and our business might ruin after this . And attack on any where in the country where the market of product is avaliable then also we migth get some loss in bussines

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
plt.figure(figsize=(10,5))
sns.countplot(x='Region',data= df_gtd)
plt.xlabel('Region')
plt.xticks(rotation=90)
plt.ylabel('No of terrorist attack in every Region')
plt.title('Terrorism activities by Region')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart shows us the Terrorism activities by Region and it is very suitable for the representation

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This chart provide the terrorism activities by region by analysing the hight of bar we can relize that which region has most terrorist activities
#
# Maximum terrorist activities in region: **Middle East and North Africa**
#
# Minimum terrorist activities in region: **Australia & Oceania**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can potentially help create a positive business impact. Understanding the regions with a high incidence of terrorist activities can say that if we want do bussiness in that are then we should take some security mesure . It can also guide investment decisions and ensure the safety of employees, assets, and operations.
#
# **nsights that led to negative growth**
#
# High frequency of terrorist activities in regions where a business operates or plans to expand, it could potentially have a negative impact on growth. Increased security costs, disruptions to operations, and potential market restrictions can hinder business expansion and profit.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
plt.figure(figsize=(10,7))
sns.countplot(data=df_gtd, x='City', order=df_gtd['City'].value_counts().head(15).index)
plt.xlabel('City affected by terrorism')
plt.xticks(rotation=90)
plt.ylabel('No of attack happen in that city ')
plt.title('Most affected city by terrorism activities',fontsize=20)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This plot shows us terrorist activities by city. This specific chart type is suitable for displaying the frequency of terrorist activities by cities.
#
# Most no of attack happenin the city named: Baghdad

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This chart provide the no of terrorist activites in top 15 cities. By analyzing the bar heights, we can identify the cities with the highest number of reported terrorist activities. The top 15 cities with the highest counts are displayed in the chart.
#
# Most attacked city is - **Baghdad**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can potentially help create a positive business impact. Understanding the cities with a high incidence of terrorist activities can inform businesses operating in those regions about potential risks and enable them to implement appropriate security measures. It can also guide investment decisions and concern about the secuurity.
#
# **Insights that led to negative growth**
#
# High frequency of terrorist activities in cities where a business operates or plans to expand, it could potentially have a negative impact on growth. Increased security costs, disruptions to operations, and potential market restrictions can hinder business expansion and profit. A single mistke can disrupt all your bussiness

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
plt.figure(figsize=(10,7))
gt=df_gtd.groupby(['Year'])["Casualties"].sum()
gt.plot(kind="line",color=["red"])
plt.xlabel('Year')
plt.xticks(rotation=90)
plt.ylabel('No of casualties')
plt.title('No of casualties by terror attack per year')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This line plot shows us that the no of terrorist activitis which cause how many people died in that attack . It allows for a clear visualization of the changes and patterns in casualty counts over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This plot provides us insight in the trends and  the number of casualties caused by terrorist attacks over the years. By analyzing the line's direction and slope, we can identify periods of high or low casualties, observe any increasing or decreasing trends,and then you can understant the pattern of terror activities.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This provides us the yearly trends of terror activities and the causulty that could give us lot of info about the terror activies so bussiness might take a good securitymesure acoording to this . This knowledge can guide the development of proactive strategies and initiatives to enhance security, mitigate risks, and protect lives and assets
#
# **insights that lead to negative growth**
#
# Negative growth may occur if the lineplot shows a consistently increasing trend or a sudden surge in the number of casualties over the years. Such insights can disturb security situation and potential challenges for businesses operating in affected areas.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
plt.figure(figsize=(10,7))
sns.countplot(data=df_gtd, x='Attack_Type',order=df_gtd['Attack_Type'].value_counts().index)
plt.xlabel('Attack Type')
plt.xticks(rotation=90)
plt.ylabel('No of attack')
plt.title('Type of terrorist activities')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This plot shows the no of attack happen form which wepon and which attack type use by terrorist the most

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This chart shows that which attack type was genrelly used by terriorist for the terrorist activitis and if government or agency can give a good look on that attack type then it might be reduced
#
# Most used attack type is **Bombing/Explosion**
#
# Minimun use attack type is **Hijacking**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Understanding the most commonly used attack types in terrorist activities allows businesses, governments, and security agencies to develop targeted security measures and counterterrorism strategies. By aligning their security protocols and risk management strategies with the prevalent attack types, businesses can enhance their preparedness, protect their assets, and ensure the safety of their employees and customers.
#
# **Insights that lead to negative growth**
#
# Insights from the countplot may not directly lead to negative growth. However, certain attack types that are more frequent and potentially more destructive, such as bombings or armed assaults, can create a negative impact on businesses operating in affected areas. Heightened security concerns, infrastructure damage, and disruptions to normal operations can lead to decreased consumer confidence, reduced economic activity, and limited growth opportunities. It becomes essential for businesses to assess the risks associated with specific attack types and implement robust security measures to mitigate potential negative impacts and ensure business continuity.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
plt.figure(figsize=(10,7))
sns.countplot(data=df_gtd, y='Target_Type')
plt.xlabel('Total no of attack')
plt.ylabel('Target Type')
plt.title('Most common target for terrorist')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The countplot is suitable for displaying the frequency of categorical variables, in this case, the target types of terror activities. By using the y-axis for the categorical variable, we can easily compare the occurrence of different target types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The countplot reveals the most common targets of terror activities. By examining the heights of the bars, we can identify the target types that have been most frequently targeted by terrorists. This insight provides valuable information about the areas or sectors that are more susceptible to terrorist attacks.
#
# Most common target of terror activities: **Private Citizens and Property**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# By understanding the most common targets of terror activities, businesses operating in those sectors or locations can better assess the associated risks and take appropriate measures to enhance security and protect their assets, employees, and customers. This proactive approach can contribute to creating a safer environment and ensuring business continuity.
#
# **Insights that lead to negative growth**
#
# The presence of high-frequency target types indicates a higher risk of attacks, which can create an environment of insecurity and instability. This may result in decreased consumer confidence, reduced investments, and potential disruptions to business operations. It becomes crucial for businesses to assess the risks, implement effective security measures, and collaborate with relevant authorities to mitigate the potential negative impacts and maintain business growth.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
plt.figure(figsize=(10,7))
sns.countplot(data=df_gtd, x='Group_Name', order=df_gtd[df_gtd['Group_Name']!='Unknown']['Group_Name'].value_counts().head(10).index)
plt.xlabel('Name of the terrorist group')
plt.xticks(rotation=90)
plt.ylabel('No of attack done by group')
plt.title('Most active terrorist group of the world')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The countplot is appropriate for displaying the frequency of categorical variables, in this case, the terrorist groups. By using the x-axis for the categorical variable, we can easily compare the number of attacks carried out by different terrorist groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This plot provide us that the top 10 most dangerous terrorist group that active in that world who is responsible for most terrorist activities
#
# Most active terrorist outfit is - **Taliban**
#
# Min active terrorist outfit is - **Kurdistan workers party**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This inform us that which is the group active in that region who is responsible for the most attack so that we can get the cover from goverment and agency for that group and we can also take some security measure for that and it chart is more useful for governement and agency for the neturalization of the terrorist group
#
# **Insights that lead to negative growth**
#
# The presence of prominent terrorist groups can create an environment of insecurity and instability, leading to reduced investor confidence, decreased tourism, and disrupted economic activities. Businesses might get limited market access and this group might take some ransome from the bussiness group that lead a disrupt in bussiness

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
plt.figure(figsize=(10,5))
sns.countplot(data=df_gtd, x='Weapon_Type',order=df_gtd[df_gtd['Weapon_Type']!='Unknown']['Weapon_Type'].value_counts().index)
plt.xlabel('Wepon used for attack')
plt.xticks(rotation=90)
plt.ylabel('No of attack')
plt.title('Weapon use for terrorist activities')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart shows very effective way that what kind of wepon use by terrorist for the terrorism

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In this chart we can say that the wepon use for terror activities is given and the most dangerous wepon use for the terror activity is - **Explosive**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# In this chart we can see that what is the most leathel wepon use for terror activity so we can take security measure to prevent the attack and with the help of the governement and agency we can tak a serious look on that wepon manufacture or ingrideant manufacture so that we can trak the wepon.
#
# **Insights that lead to negative growth**
#
# A single mistake can harm us if we loos the tracking of the weapon and it goes in the hand of the terrorist then they can attack on us this cause a big damage on the bussiness

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
India= df_gtd[df_gtd['Country']=='India']
India.head()
# Out:
#       Year  Month  Day Country      Region        state        City  \
# 1186  1972      2   22   India  South Asia        Delhi   New Delhi
# 2764  1975      1    2   India  South Asia        Bihar  Samastipur
# 3857  1976      5   26   India  South Asia        Delhi   New Delhi
# 5327  1977      9   28   India  South Asia  Maharashtra      Bombay
# 7337  1979      1   13   India  South Asia        Assam     Unknown
#
#        latitude  longitude        Attack_Type  success           Target_Type  \
# 1186  28.585836  77.153336          Hijacking        1   Airports & Aircraft
# 2764  25.863042  85.781004  Bombing/Explosion        1  Government (General)
# 3857  28.585836  77.153336  Bombing/Explosion        1   Airports & Aircraft
# 5327  19.075984  72.877656          Hijacking        1   Airports & Aircraft
# 7337  26.200605  92.937574      Armed Assault        1                Police
#
#      target_nationality               Group_Name Weapon_Type  Killed  Injured  \
# ...

# %%
plt.figure(figsize=(10,7))
sns.countplot(data= India, x='Year')
plt.xlabel('Year')
plt.xticks(rotation=90)
plt.ylabel('Attack per year')
plt.title('No of attack happen per year')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.countplot(data= India, x='City', order=India['City'].value_counts().head(15).index)
plt.xlabel('Cities')
plt.xticks(rotation=90)
plt.ylabel('No of attack happen on city')
plt.title("Terror activity happen in city most")
plt.show()

# %%
plt.figure(figsize=(10,7))
id=India.groupby(["Year"])["Casualties"].sum()
id.plot(kind="line")
plt.xlabel('Year')
plt.xticks(rotation=90)
plt.ylabel('No of casualties')
plt.title('No of casualties by terror attack ')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.countplot(data=India, x='Attack_Type')
plt.xlabel('Attack Type')
plt.xticks(rotation=90)
plt.ylabel('No of attack type')
plt.title('Most used attack type in terrorist activities')
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.countplot(data=India, y='Group_Name', order=India[India['Group_Name']!='Unknown']['Group_Name'].value_counts().head(10).index)
plt.xlabel('No of Attacks')
plt.ylabel('Terrorist Group')
plt.title('Attack done by diffrent terrorist group')
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.countplot(data=India, y='Target_Type')
plt.xlabel('Total no of attack')
plt.ylabel('Target Type')
plt.title('Most common target for terror orgniser')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We can do all the things for India what we did before for each particular country.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most terror activity in India in year: **2016**
#
# Most terror activities in city in India: **Srinagar**
#
# Most no of casualties in India: **5000**
#
# Most used weapon for terror activities in India: **Bombing and Explosion**
#
# Most active terrorist group in India: **Communist Party of India maoist (CPI-Maoist)**
#
# Most common target of terror activity in India: **Private Citizens and Property**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This understanding can aid in the development of more effective counterterrorism strategies, resource allocation for security measures, and initiatives focused on mitigating the consequences of such attacks. Ultimately, these actions can contribute to creating a safer environment, enhancing public confidence, and fostering positive social and economic growth.
#
# **Insights that lead to negative growth**
#
# Heightened security concerns, loss of lives, disruptions in business activities, and a decline in tourism and investments can adversely affect economic growth and development. Therefore, it is crucial to use these insights to implement effective counterterrorism measures and preventive actions to minimize the negative impact and promote sustainable growth.

# %% [markdown]
# #####Chart - 11

# %%
# Chart - 11 visualization code
plt.figure(figsize=(10, 10))
country_counts = df_gtd['Country'].value_counts()
top_countries = country_counts.head(10)
plt.pie(top_countries, labels=top_countries.index, autopct='%1.1f%%')
plt.title('Proportion of Terrorist Activities by Country')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pie chart was chosen because it effectively shows the proportion or distribution of terrorist activities in different countries. It provides a visual representation of the relative sizes of each country's contribution to the total number of terrorist activities.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pie chart allows us to identify the top countries with the highest proportion of terrorist activities.
#
# It shows which countries are most affected by terrorism and provides a comparative view of their contributions.
#
# It can highlight countries that may require special attention or resources in terms of security measures, risk assessment, and mitigation strategies. The chart can also reveal any significant disparities in the distribution of terrorist activities among countries.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# Enabling businesses to prioritize and allocate resources effectively based on the countries with the highest proportions of terrorist activities.
#
# Facilitating collaboration with government agencies and security organizations to address the challenges posed by terrorism in specific countries.
#
# **negative growth impacts**
#
# Businesses may face limitations or increased challenges when operating in countries with a high proportion of terrorist activities. This could lead to disrupted operations, increased security costs, and restricted market expansion. Negative perceptions or associations with countries heavily affected by terrorism can impact consumer confidence, investor sentiment, and business partnerships, potentially resulting in reduced growth opportunities.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
grouped_data = df_gtd.groupby(['Region', 'Attack_Type']).size().unstack()
grouped_data['Total'] = grouped_data.sum(axis=1)
grouped_data_percentage = grouped_data.div(grouped_data['Total'], axis=0) * 100
plt.style.use('seaborn')
grouped_data_percentage.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Distribution of Attack Types by Region')
plt.xlabel('Region')
plt.ylabel('Percentage of attack')
plt.legend(title='Attack Type', bbox_to_anchor=(1, 1))
plt.show()
# Out:
# <ipython-input-128-bb429abdf743>:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A stacked bar chart is suitable for displaying the distribution of attack types by region because it allows for easy comparison of the proportions of different attack types within each region

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Regional Variations:** It enables comparison of attack type distributions across different regions, highlighting variations in the prevalence of specific attack types.
#
# **Dominant Attack Types:** The chart can reveal the most common attack types within each region.
#
# **Regional Patterns:** It may uncover patterns or trends in the distribution of attack types.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Understanding the prevalent attack types in different regions can assist in developing targeted security strategies and measures to mitigate risks effectively.To understand regional patterns can aid in allocating resources, such as security personnel or infrastructure, based on therat perception
#
# **negative growth**
#
# Highly destructive attack types in certain regions, it could indicate a heightened risk environment. This could potentially result in negative growth or impact sectors such as tourism, investment, or local economies.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
plt.figure(figsize=(12, 8))
df_gtd['Region'].value_counts().head(10).plot(kind='pie', autopct='%1.1f%%')
plt.title('Terrorist Activities by Region')
plt.ylabel('')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie chart is an effective way to represent percentages for data . In this case, it allows us to visually understand the distribution of terrorist activities across different regions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pie chart provides a clear visualization of the relative distribution of terrorist activities among the top 10 regions.
#
# It helps identify the regions with the highest and lowest proportions of terrorist activities.
#
# It allows for a quick comparison of the contribution of each region to the overall terrorist activities.
#
# max terrorist attack in region: **Middle East & North Africa**
#
# min terrorist attack in region:**East Asia**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We can see that most peaceful region is East Asia so we can set up a good bussiness with some security measure and if we want to set up our bussiness then we have to take a good security measure accordin to that reason
#
# **negative growth**
#
# If the pie chart reveals a significant concentration of terrorist activities in specific regions, it may raise concerns among potential investors, customers, and partners. This can result in negative perceptions and reluctance to engage in business activities in those regions.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
plt.figure(figsize=(12,7))
sns.heatmap(data=df_gtd.corr(), annot=True, cmap="RdYlGn")
plt.xlabel('Features')
plt.ylabel('Features')
plt.title('Correlation between different features')
plt.show()
# Out:
# <ipython-input-42-5ed0f55f0536>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=df_gtd.corr(), annot=True, cmap="RdYlGn")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The selected heatmap chart is suitable for visualizing the correlation matrix as it allows us to identify patterns and trends in the data. By examining the color-coded correlation, we can gain insights into the strength and direction of relationships between variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This chart show us what is the positive and negative relation  between fetures of data . For example, positive correlations between 'Killed' and 'Casualties' indicate that higher numbers of killed individuals are associated with higher casualty counts. Similarly, positive correlations between 'Injured' and 'Casualties' suggest that higher numbers of injured individuals are also associated with higher casualty counts.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(data= df_gtd.head(10))
plt.xlabel('Features')
plt.ylabel('Features')
plt.title('Correlation between different features')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We picked up this chart because it allow us to visualize the data by diffrent variable of the dataset. By pointing each variable against each other variable
# we can gain insights into the correlations, patterns, and distributions among the variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Strength of Correlation:** We can identify the strength and direction of correlations between different variables. For example, we can see if there is a positive or negative correlation between the number of casualties and the number of people killed in terrorist attacks.
#
# **Direction of Correlation:** We can examine the distribution of each variable and identify any patterns or outliers. This helps us understand the range and spread of values for each variable.
#
# **Identifying Relationships:** We can observe how different variables interact with each other. For example, we can see if there is a relationship between the type of attack and the success of the attack.
#
# **Data Understanding:** We can identify any outliers or unusual observations in the dataset that may require further investigation.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Analyzing global terrorism data can provide valuable insights for businesses, particularly those with international operations or interests in regions prone to terrorism. Here are some suggestions for businessmen looking to achieve their business objectives through the analysis of global terrorism data:
#
# **Define Clear Business Objectives:**
#
# Start by clearly defining your business objectives. What specific goals are you trying to achieve through the analysis of terrorism data? For example, are you looking to assess risks, enhance security measures, or make strategic decisions regarding business expansion?
#
# **Data Integration:**
#
# Integrate terrorism data with other relevant datasets such as economic indicators, political stability indices, and regional demographics to provide context for your analysis.
#
# **Risk Assessment:**
#
# Conduct a comprehensive risk assessment that considers the impact of terrorism on your business operations. Evaluate the potential risks associated with specific geographic regions or business units.
#
# **Trend Analysis:**
#
# Analyze historical data to identify trends and patterns in terrorism incidents. Are certain regions or types of attacks becoming more or less common over time?
#
# **Impact Assessment:**
#
# Assess the potential impact of terrorism on your supply chain, workforce, and customer base. Consider the financial, operational, and reputational consequences.
#
# **Predictive Modeling:**
#
# Develop predictive models that can forecast terrorism risk in specific regions. Machine learning techniques can be valuable for this purpose.
#
# **Scenario Planning:**
#
# Use the insights gained from your analysis to develop various scenarios and contingency plans. How would your business respond to different levels of terrorism risk?
#
# **Security Measures:**
#
# Based on your analysis, enhance security measures in high-risk regions. This might include physical security, cybersecurity, and employee safety protocols.
#
# **Market Entry and Expansion Strategies:**
#
# If you're considering entering new markets or expanding into regions with terrorism concerns, use your analysis to make informed decisions. Evaluate the trade-offs and mitigation strategies.
#
# **Communication and Crisis Management:**
#
# Develop communication and crisis management plans that outline how your business will respond to terrorism-related incidents. Ensure that employees are trained on these plans.
#
# **Consult Experts:**
#
# Consider consulting with security experts, risk assessment firms, and geopolitical analysts who specialize in terrorism-related issues to gain deeper insights.
#
# Remember that the approach and tools used for analyzing global terrorism data should align with your specific business goals and available resources. Collaboration with experts and staying informed about global security issues are essential for effective risk management.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# A comprehensive analysis of global terrorism data serves as a powerful tool for gaining deeper insights into the complex and evolving nature of terrorism worldwide. In this EDA (Exploratory Data Analysis) project, we have delved into various facets of terrorism data to uncover trends, patterns, and important takeaways that are crucial for understanding this critical global issue.
#
# We have examined how the frequency and severity of terrorist incidents have evolved over time. This provides important context for understanding the dynamics of terrorism and its response by governments and international organizations.
#
# By mapping terrorism incidents, we have identified hotspots and regions where terrorism is particularly prevalent. This can aid in targeted risk assessment and mitigation efforts for businesses and governments operating in these areas.
#
# Analyzing the types of attacks (e.g., bombings, kidnappings, shootings) has shed light on the tactics employed by terrorist groups. Understanding these tactics can inform security measures and preparedness strategies.
#
# We have explored the types of targets chosen by terrorists, which can range from civilian populations to government installations. This information is crucial for assessing potential vulnerabilities and developing protective measures.
#
# In conclusion, this EDA project has provided valuable insights into the global terrorism landscape. It underscores the importance of data-driven analysis and informed decision-making when dealing with the multifaceted challenges posed by terrorism. By continuing to explore and analyze terrorism data, we can work towards a better understanding of the factors driving this phenomenon and develop more effective strategies for preventing and mitigating its impact. This knowledge is not only relevant for policymakers and security experts but also for businesses, organizations, and individuals seeking to navigate an increasingly complex global landscape.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
